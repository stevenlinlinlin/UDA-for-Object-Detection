# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
# !pwd
# Out:
# /bin/bash: /home/stevenlin/anaconda3/envs/tensorflow/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /home/stevenlin/ntu/cvpdl/hw3/ConfMix

# %%
# Read csv file
df = pd.read_csv('./runs/train/cityscapes2foggy4report/results.csv')
df["     metrics/mAP_0.5"]
# Out:
# 0     0.49133
# 1     0.43004
# 2     0.44288
# 3     0.41578
# 4     0.39943
# 5     0.40382
# 6     0.42272
# 7     0.41866
# 8     0.43737
# 9     0.45681
# 10    0.44598
# 11    0.46289
# 12    0.47801
# 13    0.47567
# 14    0.46024
# 15    0.48480
# 16    0.47689
# 17    0.49707
# 18    0.46567
# 19    0.46212
# 20    0.48284
# 21    0.47343
# 22    0.48760
# 23    0.49320
# 24    0.48258
# 25    0.49629
# 26    0.46451
# 27    0.48451
# 28    0.49917
# 29    0.49921
# 30    0.49148
# 31    0.49258
# 32    0.48555
# 33    0.48484
# 34    0.49832
# 35    0.50195
# 36    0.49398
# 37    0.51553
# 38    0.48774
# 39    0.51013
# 40    0.50477
# 41    0.49662
# 42    0.49849
# 43    0.50085
# 44    0.49921
# 45    0.51942
# 46    0.50755
# 47    0.51143
# 48    0.51020
# 49    0.51063
# Name:      metrics/mAP_0.5, dtype: float64

# %%
y = df["     metrics/mAP_0.5"]
x = df["               epoch"]
plt.title('trained target model on the target validation set')
plt.xlabel('epoch')
plt.ylabel('mAP_0.5')
plt.plot(x, y)
